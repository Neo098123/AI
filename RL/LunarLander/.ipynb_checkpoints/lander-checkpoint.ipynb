# %%
from platform import python_version
import gym
from gym import envs
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import itertools
print(python_version())
print(tf.__version__)
# Out:
# 3.7.5
# 2.2.0

# %%
# Definindo nosso buffer de experience replay:

class ExperienceReplay():
    def __init__(self, mem_max, input_dims):
        
        self.mem_max = mem_max       # Tamanho máximo do buffer
        self.mem_counter = 0         # Contador de quantos elementos o buffer possui



        # inicializando experiências guardadas

        self.s = np.zeros((self.mem_max, *input_dims), dtype=np.float32)  # Estado 1
        self.s2 = np.zeros((self.mem_max, *input_dims),dtype=np.float32)  # Estado 2
        self.r = np.zeros(self.mem_max, dtype = np.float32)               # Recompensas
        self.a = np.zeros(self.mem_max, dtype = np.int32)                 # Ações
        self.terminal = np.zeros(self.mem_max, dtype=np.int32)            # Se a memória é de um estado terminal ou não
        

    def store_transition(self, s, a, r, s2, teminado):
        index = self.mem_counter % self.mem_max
        self.s[index] = s                                   # Estado 1
        self.s2[index] = s2                                 # Estado 2
        self.r[index] = r                                   # Reward da Experiência
        self.a[index] = a                                   # Ação da Experiência
        self.terminal[index] = 1 - int(teminado)            # Caso a memória seja terminal
        self.mem_counter += 1                               # Incrementando o contador


    def sample_buffer(self, batch_size):
        mem_max = min(self.mem_counter, self.mem_max)
        batch = np.random.choice(mem_max, batch_size, replace=False)

        s = self.s[batch]
        s2 = self.s2[batch]
        r = self.r[batch]
        a = self.a[batch]
        terminal = self.terminal[batch]
        return s, a, r, s2, terminal

# %%
# Agora montaremos a estrutura de nossa DQN() :

##

def fazerDQN(alpha, n_acoes, input_dims, fc1, fc2):
    layers = tf.keras.layers
    DQN = tf.keras.models.Sequential()
    DQN.add(layers.Flatten(input_shape=(input_dims)))
    DQN.add(layers.Dense(fc1, activation='relu'))
    DQN.add(layers.Dense(fc2, activation='relu'))
    DQN.add(layers.Dense(n_acoes, activation=None))
    
    
    DQN.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=alpha),loss='huber_loss')

    return DQN

# %%
class Agent():
    def __init__(self, alpha, gamma, n_acoes, epsilon, batch_size, input_dims,
                 epsilon_dec=1e-3, epsilon_end=0.01, mem_max=1000000, fname='dqn_model.h5' ):


        self.acoes = [i for i in range(n_acoes)]
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_dec = epsilon_dec
        self.eps_min = epsilon_end
        self.batch_size = batch_size
        self.model_file = fname
        self.memoria = ExperienceReplay(mem_max, input_dims)
        self.q_eval = fazerDQN(alpha, n_acoes, input_dims, 256,256) ##

    def store_transition(self, s, a, r, s2, terminado):
        self.memoria.store_transition(s, a, r, s2, terminado)

    def escolher_acao(self, obs):
        if np.random.random() < self.epsilon:
            acao = np.random.choice(self.acoes)
        else:
            s = np.array([obs])
            acoes = self.q_eval.predict(s) ##

            acao = np.argmax(acoes)
        return acao

    def learn(self):
        if self.memoria.mem_counter < self.batch_size:
            return
        s, a, r, s2, terminados = self.memoria.sample_buffer(self.batch_size)
        q_eval = self.q_eval.predict(s) ##
        q_next = self.q_eval.predict(s2) ##

        q_target = np.copy(q_eval)
        batch_index = np.arange(self.batch_size, dtype=np.int32)

        q_target[batch_index, a] = r + self.gamma*np.max(q_next, axis=1)*terminados

        self.q_eval.train_on_batch(s, q_target) ##

        self.epsilon = self.epsilon - self.epsilon_dec if self.epsilon > self.eps_min else self.eps_min

    def save_model(self):
        self.q_eval.save(self.model_file)   ##
    def load_model(self):
        self.q_eval = tf.keras.models.load_model(self.model_file)    ##

# %%
# Carregando agente, ambiente e hiperparametros

lr = 0.001
n_games = 500

env = gym.make('LunarLander-v2')

agent = Agent(gamma=0.99, epsilon = 1.0, alpha=lr, input_dims=env.observation_space.shape,
              n_acoes=env.action_space.n, mem_max=1000000,
              batch_size=64, epsilon_end=0.01)
try:
    agent.load_model()  ##
except:
    pass

# %%
# Treinando o modelo e salvando:


scores = []
eps_history = []
for i in range(n_games):
    done = False
    score = 0
    observation = env.reset()
    while not done:
        action = agent.escolher_acao(observation)        
        observation_, reward, done, info = env.step(action)
        score += reward
        agent.store_transition(observation, action, reward, observation_, done)
        observation = observation_
        agent.learn()
    eps_history.append(agent.epsilon)
    scores.append(score)
    
    avg_score = np.mean(scores[-100:])
    print("episode: ", i, "score %.2f" % score, "average_score %.2f" % avg_score, "epsilon %.2f" % agent.epsilon)
    agent.save_model()
# Out:
# episode:  0 score -241.82 average_score -241.82 epsilon 0.98
# episode:  1 score -128.09 average_score -184.95 epsilon 0.89
# episode:  2 score -292.77 average_score -220.89 epsilon 0.75
# episode:  3 score -22.51 average_score -171.30 epsilon 0.66
# episode:  4 score -311.47 average_score -199.33 epsilon 0.54
# episode:  5 score 16.15 average_score -163.42 epsilon 0.41
# episode:  6 score -76.54 average_score -151.01 epsilon 0.22
# episode:  7 score -161.79 average_score -152.36 epsilon 0.01
# episode:  8 score -77.03 average_score -143.99 epsilon 0.01
# episode:  9 score -71.62 average_score -136.75 epsilon 0.01
# episode:  10 score -20.69 average_score -126.20 epsilon 0.01
# episode:  11 score -17.64 average_score -117.15 epsilon 0.01
# episode:  12 score -73.69 average_score -113.81 epsilon 0.01
# episode:  13 score -126.64 average_score -114.72 epsilon 0.01
# episode:  14 score -264.53 average_score -124.71 epsilon 0.01
# episode:  15 score -55.15 average_score -120.36 epsilon 0.01
# episode:  16 score -46.79 average_score -116.04 epsilon 0.01
# episode:  17 score -69.57 average_score -113.45 epsilon 0.01
# episode:  18 score -46.19 average_score -109.91 epsilon 0.01
# episode:  19 score -58.78 average_score -107.36 epsilon 0.01
# episode:  20 score -35.82 average_score -103.95 epsilon 0.01
# episode:  21 score -163.52 average_score -106.66 epsilon 0.01
# episode:  22 score -3.54 average_score -102.18 epsilon 0.01
# episode:  23 score -31.06 average_score -99.21 epsilon 0.01
# episode:  24 score -32.01 average_score -96.52 epsilon 0.01
# episode:  25 score -9.49 average_score -93.18 epsilon 0.01
# episode:  26 score -27.99 average_score -90.76 epsilon 0.01
# episode:  27 score -32.05 average_score -88.67 epsilon 0.01
# episode:  28 score -25.61 average_score -86.49 epsilon 0.01
# episode:  29 score -27.45 average_score -84.52 epsilon 0.01
# episode:  30 score -44.89 average_score -83.24 epsilon 0.01
# episode:  31 score -26.45 average_score -81.47 epsilon 0.01
# episode:  32 score -33.00 average_score -80.00 epsilon 0.01
# episode:  33 score 24.92 average_score -76.92 epsilon 0.01
# episode:  34 score -8.14 average_score -74.95 epsilon 0.01
# episode:  35 score -21.87 average_score -73.48 epsilon 0.01
# episode:  36 score -29.40 average_score -72.28 epsilon 0.01
# episode:  37 score -10.57 average_score -70.66 epsilon 0.01
# episode:  38 score -38.89 average_score -69.85 epsilon 0.01
# episode:  39 score -52.40 average_score -69.41 epsilon 0.01
# episode:  40 score -119.83 average_score -70.64 epsilon 0.01
# episode:  41 score -35.11 average_score -69.79 epsilon 0.01
# episode:  42 score -92.63 average_score -70.32 epsilon 0.01
# episode:  43 score -75.67 average_score -70.45 epsilon 0.01
# episode:  44 score -84.43 average_score -70.76 epsilon 0.01
# episode:  45 score -35.96 average_score -70.00 epsilon 0.01
# episode:  46 score -20.91 average_score -68.96 epsilon 0.01
# episode:  47 score -30.95 average_score -68.16 epsilon 0.01
# episode:  48 score 16.40 average_score -66.44 epsilon 0.01
# episode:  49 score -26.35 average_score -65.64 epsilon 0.01
# episode:  50 score -45.99 average_score -65.25 epsilon 0.01
# episode:  51 score -76.59 average_score -65.47 epsilon 0.01
# episode:  52 score -95.30 average_score -66.03 epsilon 0.01
# episode:  53 score -0.45 average_score -64.82 epsilon 0.01
# episode:  54 score -40.14 average_score -64.37 epsilon 0.01
# episode:  55 score -16.73 average_score -63.52 epsilon 0.01
# episode:  56 score -41.81 average_score -63.14 epsilon 0.01
# episode:  57 score -18.29 average_score -62.36 epsilon 0.01
# episode:  58 score -194.85 average_score -64.61 epsilon 0.01
# episode:  59 score -69.23 average_score -64.69 epsilon 0.01
# episode:  60 score -33.78 average_score -64.18 epsilon 0.01
# episode:  61 score -142.10 average_score -65.44 epsilon 0.01
# episode:  62 score -25.57 average_score -64.80 epsilon 0.01
# episode:  63 score -20.74 average_score -64.12 epsilon 0.01
# episode:  64 score -9.72 average_score -63.28 epsilon 0.01
# episode:  65 score -75.81 average_score -63.47 epsilon 0.01
# episode:  66 score -32.91 average_score -63.01 epsilon 0.01
# episode:  67 score -0.35 average_score -62.09 epsilon 0.01
# episode:  68 score -29.12 average_score -61.61 epsilon 0.01
# episode:  69 score -34.97 average_score -61.23 epsilon 0.01
# episode:  70 score -74.86 average_score -61.42 epsilon 0.01
# episode:  71 score -43.51 average_score -61.18 epsilon 0.01
# episode:  72 score -4.02 average_score -60.39 epsilon 0.01
# episode:  73 score -701.61 average_score -69.06 epsilon 0.01
# episode:  74 score -670.33 average_score -77.07 epsilon 0.01
# episode:  75 score -445.97 average_score -81.93 epsilon 0.01
# episode:  76 score -582.39 average_score -88.43 epsilon 0.01
# episode:  77 score -222.44 average_score -90.15 epsilon 0.01
# episode:  78 score -357.73 average_score -93.53 epsilon 0.01
# episode:  79 score -300.08 average_score -96.12 epsilon 0.01
# episode:  80 score -114.98 average_score -96.35 epsilon 0.01
# episode:  81 score -43.51 average_score -95.70 epsilon 0.01
# episode:  82 score -14.48 average_score -94.73 epsilon 0.01
# episode:  83 score -42.33 average_score -94.10 epsilon 0.01
# episode:  84 score -261.46 average_score -96.07 epsilon 0.01
# episode:  85 score 114.84 average_score -93.62 epsilon 0.01
# episode:  86 score -51.31 average_score -93.13 epsilon 0.01
# episode:  87 score -34.17 average_score -92.46 epsilon 0.01
# episode:  88 score 95.82 average_score -90.35 epsilon 0.01
# episode:  89 score 115.61 average_score -88.06 epsilon 0.01
# episode:  90 score 0.35 average_score -87.09 epsilon 0.01
# episode:  91 score -23.99 average_score -86.40 epsilon 0.01
# episode:  92 score -25.88 average_score -85.75 epsilon 0.01
# episode:  93 score -47.99 average_score -85.35 epsilon 0.01
# episode:  94 score -279.41 average_score -87.39 epsilon 0.01
# episode:  95 score -56.36 average_score -87.07 epsilon 0.01
# episode:  96 score -41.68 average_score -86.60 epsilon 0.01
# episode:  97 score -44.35 average_score -86.17 epsilon 0.01
# episode:  98 score -28.46 average_score -85.59 epsilon 0.01
# episode:  99 score -36.80 average_score -85.10 epsilon 0.01
# episode:  100 score -27.94 average_score -82.96 epsilon 0.01
# episode:  101 score 117.81 average_score -80.50 epsilon 0.01
# episode:  102 score -10.36 average_score -77.68 epsilon 0.01
# episode:  103 score 150.70 average_score -75.94 epsilon 0.01
# episode:  104 score -55.77 average_score -73.39 epsilon 0.01
# episode:  105 score -41.33 average_score -73.96 epsilon 0.01
# episode:  106 score -11.07 average_score -73.31 epsilon 0.01
# episode:  107 score -39.12 average_score -72.08 epsilon 0.01
# episode:  108 score -43.88 average_score -71.75 epsilon 0.01
# episode:  109 score -19.66 average_score -71.23 epsilon 0.01
# episode:  110 score 219.23 average_score -68.83 epsilon 0.01
# episode:  111 score -25.82 average_score -68.91 epsilon 0.01
# episode:  112 score -46.56 average_score -68.64 epsilon 0.01
# episode:  113 score -106.82 average_score -68.44 epsilon 0.01
# episode:  114 score 218.87 average_score -63.61 epsilon 0.01
# episode:  115 score 99.81 average_score -62.06 epsilon 0.01
# episode:  116 score -2.14 average_score -61.61 epsilon 0.01
# episode:  117 score 233.36 average_score -58.58 epsilon 0.01
# episode:  118 score 16.99 average_score -57.95 epsilon 0.01
# episode:  119 score 14.19 average_score -57.22 epsilon 0.01
# episode:  120 score 236.04 average_score -54.50 epsilon 0.01
# episode:  121 score 255.69 average_score -50.31 epsilon 0.01
# episode:  122 score 210.47 average_score -48.17 epsilon 0.01
# episode:  123 score -141.73 average_score -49.28 epsilon 0.01
# episode:  124 score 218.93 average_score -46.77 epsilon 0.01
# episode:  125 score 224.26 average_score -44.43 epsilon 0.01
# episode:  126 score 155.00 average_score -42.60 epsilon 0.01
# episode:  127 score -237.04 average_score -44.65 epsilon 0.01
# episode:  128 score 9.23 average_score -44.30 epsilon 0.01
# episode:  129 score -13.53 average_score -44.16 epsilon 0.01
# episode:  130 score 41.19 average_score -43.30 epsilon 0.01
# episode:  131 score 248.25 average_score -40.55 epsilon 0.01
# episode:  132 score 246.79 average_score -37.76 epsilon 0.01
# episode:  133 score 44.30 average_score -37.56 epsilon 0.01
# episode:  134 score 216.88 average_score -35.31 epsilon 0.01
# episode:  135 score 237.68 average_score -32.72 epsilon 0.01
# episode:  136 score 258.13 average_score -29.84 epsilon 0.01
# episode:  137 score 242.94 average_score -27.31 epsilon 0.01
# episode:  138 score 201.28 average_score -24.91 epsilon 0.01
# episode:  139 score 249.90 average_score -21.88 epsilon 0.01
# episode:  140 score 271.75 average_score -17.97 epsilon 0.01
# episode:  141 score 247.40 average_score -15.14 epsilon 0.01
# episode:  142 score 219.41 average_score -12.02 epsilon 0.01
# episode:  143 score 6.18 average_score -11.20 epsilon 0.01
# episode:  144 score 265.13 average_score -7.71 epsilon 0.01
# episode:  145 score 249.05 average_score -4.86 epsilon 0.01
# episode:  146 score 199.33 average_score -2.65 epsilon 0.01
# episode:  147 score -158.40 average_score -3.93 epsilon 0.01
# episode:  148 score 288.74 average_score -1.21 epsilon 0.01
# episode:  149 score -184.69 average_score -2.79 epsilon 0.01
# episode:  150 score 287.28 average_score 0.54 epsilon 0.01
# episode:  151 score 272.41 average_score 4.03 epsilon 0.01
# episode:  152 score 159.01 average_score 6.58 epsilon 0.01
# episode:  153 score 246.92 average_score 9.05 epsilon 0.01
# episode:  154 score 259.83 average_score 12.05 epsilon 0.01
# episode:  155 score 242.32 average_score 14.64 epsilon 0.01
# episode:  156 score 271.78 average_score 17.78 epsilon 0.01
# episode:  157 score 279.23 average_score 20.75 epsilon 0.01
# episode:  158 score 256.43 average_score 25.27 epsilon 0.01
# episode:  159 score 268.66 average_score 28.64 epsilon 0.01
# episode:  160 score -202.21 average_score 26.96 epsilon 0.01
# episode:  161 score 261.47 average_score 31.00 epsilon 0.01
# episode:  162 score 278.47 average_score 34.04 epsilon 0.01
# episode:  163 score 269.51 average_score 36.94 epsilon 0.01
# episode:  164 score -263.81 average_score 34.40 epsilon 0.01
# episode:  165 score 227.42 average_score 37.43 epsilon 0.01
# episode:  166 score 149.53 average_score 39.25 epsilon 0.01
# episode:  167 score 273.81 average_score 42.00 epsilon 0.01
# episode:  168 score 190.62 average_score 44.19 epsilon 0.01
# episode:  169 score 57.99 average_score 45.12 epsilon 0.01
# episode:  170 score 289.43 average_score 48.77 epsilon 0.01
# episode:  171 score 273.01 average_score 51.93 epsilon 0.01
# episode:  172 score 42.54 average_score 52.40 epsilon 0.01
# episode:  173 score 263.13 average_score 62.04 epsilon 0.01
# episode:  174 score 280.47 average_score 71.55 epsilon 0.01
# episode:  175 score 267.30 average_score 78.68 epsilon 0.01
# episode:  176 score 226.47 average_score 86.77 epsilon 0.01
# episode:  177 score 225.60 average_score 91.25 epsilon 0.01
# episode:  178 score 251.89 average_score 97.35 epsilon 0.01
# episode:  179 score 238.45 average_score 102.73 epsilon 0.01
# episode:  180 score 63.56 average_score 104.52 epsilon 0.01
# episode:  181 score 208.22 average_score 107.04 epsilon 0.01
# episode:  182 score 294.63 average_score 110.13 epsilon 0.01
# episode:  183 score 157.19 average_score 112.12 epsilon 0.01
# episode:  184 score 277.86 average_score 117.52 epsilon 0.01
# episode:  185 score 223.37 average_score 118.60 epsilon 0.01
# episode:  186 score 271.83 average_score 121.83 epsilon 0.01
# episode:  187 score 279.86 average_score 124.97 epsilon 0.01
# episode:  188 score 247.38 average_score 126.49 epsilon 0.01
# episode:  189 score 270.02 average_score 128.03 epsilon 0.01
# episode:  190 score 63.81 average_score 128.67 epsilon 0.01
# episode:  191 score 262.86 average_score 131.54 epsilon 0.01
# episode:  192 score 261.46 average_score 134.41 epsilon 0.01
# episode:  193 score 274.21 average_score 137.63 epsilon 0.01
# episode:  194 score 234.78 average_score 142.77 epsilon 0.01
# episode:  195 score -29.92 average_score 143.04 epsilon 0.01
# episode:  196 score 22.96 average_score 143.68 epsilon 0.01
# episode:  197 score 248.28 average_score 146.61 epsilon 0.01
# episode:  198 score 273.21 average_score 149.63 epsilon 0.01
# episode:  199 score 69.04 average_score 150.69 epsilon 0.01
# episode:  200 score 261.27 average_score 153.58 epsilon 0.01
# episode:  201 score 253.23 average_score 154.93 epsilon 0.01
# episode:  202 score 286.55 average_score 157.90 epsilon 0.01
# episode:  203 score 209.52 average_score 158.49 epsilon 0.01
# episode:  204 score 288.58 average_score 161.93 epsilon 0.01
# episode:  205 score 285.71 average_score 165.20 epsilon 0.01
# episode:  206 score 279.94 average_score 168.11 epsilon 0.01
# episode:  207 score 251.93 average_score 171.02 epsilon 0.01
# episode:  208 score 7.93 average_score 171.54 epsilon 0.01
# episode:  209 score 6.45 average_score 171.80 epsilon 0.01
# episode:  210 score 18.38 average_score 169.80 epsilon 0.01
# episode:  211 score 248.18 average_score 172.54 epsilon 0.01
# episode:  212 score -139.24 average_score 171.61 epsilon 0.01
# episode:  213 score 184.88 average_score 174.53 epsilon 0.01
# episode:  214 score 61.21 average_score 172.95 epsilon 0.01
# episode:  215 score 260.34 average_score 174.55 epsilon 0.01
# episode:  216 score 59.41 average_score 175.17 epsilon 0.01
# episode:  217 score -11.24 average_score 172.72 epsilon 0.01
# episode:  218 score -10.43 average_score 172.45 epsilon 0.01
# episode:  219 score -41.13 average_score 171.90 epsilon 0.01
# episode:  220 score -1.55 average_score 169.52 epsilon 0.01
# episode:  221 score 293.17 average_score 169.90 epsilon 0.01
# episode:  222 score 234.30 average_score 170.13 epsilon 0.01
# episode:  223 score 265.71 average_score 174.21 epsilon 0.01
# episode:  224 score -39.60 average_score 171.62 epsilon 0.01
# episode:  225 score 265.00 average_score 172.03 epsilon 0.01
# episode:  226 score 238.48 average_score 172.86 epsilon 0.01
# episode:  227 score -105.86 average_score 174.18 epsilon 0.01
# episode:  228 score -22.62 average_score 173.86 epsilon 0.01
# episode:  229 score 165.00 average_score 175.64 epsilon 0.01
# episode:  230 score -40.75 average_score 174.82 epsilon 0.01
# episode:  231 score 193.89 average_score 174.28 epsilon 0.01
# episode:  232 score 218.31 average_score 174.00 epsilon 0.01
# episode:  233 score 154.81 average_score 175.10 epsilon 0.01
# episode:  234 score 260.76 average_score 175.54 epsilon 0.01
# episode:  235 score 224.68 average_score 175.41 epsilon 0.01
# episode:  236 score 241.84 average_score 175.25 epsilon 0.01
# episode:  237 score 249.41 average_score 175.31 epsilon 0.01
# episode:  238 score 200.37 average_score 175.30 epsilon 0.01
# episode:  239 score 196.62 average_score 174.77 epsilon 0.01
# episode:  240 score 248.96 average_score 174.54 epsilon 0.01
# episode:  241 score 236.30 average_score 174.43 epsilon 0.01
# episode:  242 score 236.93 average_score 174.61 epsilon 0.01
# episode:  243 score 258.91 average_score 177.13 epsilon 0.01
# episode:  244 score 254.26 average_score 177.02 epsilon 0.01
# episode:  245 score 232.40 average_score 176.86 epsilon 0.01
# episode:  246 score 249.14 average_score 177.36 epsilon 0.01
# episode:  247 score 268.41 average_score 181.62 epsilon 0.01
# episode:  248 score 255.27 average_score 181.29 epsilon 0.01
# episode:  249 score 227.10 average_score 185.41 epsilon 0.01
# episode:  250 score 265.74 average_score 185.19 epsilon 0.01
# episode:  251 score 236.44 average_score 184.83 epsilon 0.01
# episode:  252 score 165.05 average_score 184.89 epsilon 0.01
# episode:  253 score 267.61 average_score 185.10 epsilon 0.01
# episode:  254 score -41.43 average_score 182.09 epsilon 0.01
# episode:  255 score 279.37 average_score 182.46 epsilon 0.01
# episode:  256 score 232.75 average_score 182.07 epsilon 0.01
# episode:  257 score 265.47 average_score 181.93 epsilon 0.01
# episode:  258 score 261.74 average_score 181.98 epsilon 0.01
# episode:  259 score 250.44 average_score 181.80 epsilon 0.01
# episode:  260 score 279.56 average_score 186.62 epsilon 0.01
# episode:  261 score 249.76 average_score 186.50 epsilon 0.01
# episode:  262 score 260.23 average_score 186.32 epsilon 0.01
# episode:  263 score 251.48 average_score 186.14 epsilon 0.01
# episode:  264 score 94.66 average_score 189.72 epsilon 0.01
# episode:  265 score 296.40 average_score 190.41 epsilon 0.01
# episode:  266 score -109.66 average_score 187.82 epsilon 0.01
# episode:  267 score 213.88 average_score 187.22 epsilon 0.01
# episode:  268 score 267.90 average_score 187.99 epsilon 0.01
# episode:  269 score 238.40 average_score 189.80 epsilon 0.01
# episode:  270 score 287.82 average_score 189.78 epsilon 0.01
# episode:  271 score 256.41 average_score 189.62 epsilon 0.01
# episode:  272 score 240.13 average_score 191.59 epsilon 0.01
# episode:  273 score 297.45 average_score 191.94 epsilon 0.01
# episode:  274 score 190.85 average_score 191.04 epsilon 0.01
# episode:  275 score 194.87 average_score 190.31 epsilon 0.01
# episode:  276 score -204.36 average_score 186.01 epsilon 0.01
# episode:  277 score 259.77 average_score 186.35 epsilon 0.01
# episode:  278 score 227.96 average_score 186.11 epsilon 0.01
# episode:  279 score 279.06 average_score 186.51 epsilon 0.01
# episode:  280 score 247.95 average_score 188.36 epsilon 0.01
# episode:  281 score 205.58 average_score 188.33 epsilon 0.01
# episode:  282 score 289.34 average_score 188.28 epsilon 0.01
# episode:  283 score 262.16 average_score 189.33 epsilon 0.01
# episode:  284 score 252.06 average_score 189.07 epsilon 0.01
# episode:  285 score 32.28 average_score 187.16 epsilon 0.01
# episode:  286 score 285.88 average_score 187.30 epsilon 0.01
# episode:  287 score 300.14 average_score 187.50 epsilon 0.01
# episode:  288 score -11.48 average_score 184.91 epsilon 0.01
# episode:  289 score -152.40 average_score 180.69 epsilon 0.01
# episode:  290 score 283.01 average_score 182.88 epsilon 0.01
# episode:  291 score 154.62 average_score 181.80 epsilon 0.01
# episode:  292 score 247.76 average_score 181.66 epsilon 0.01
# episode:  293 score -242.83 average_score 176.49 epsilon 0.01
# episode:  294 score 254.30 average_score 176.69 epsilon 0.01
# episode:  295 score 286.34 average_score 179.85 epsilon 0.01
# episode:  296 score 257.09 average_score 182.19 epsilon 0.01
# episode:  297 score 255.88 average_score 182.27 epsilon 0.01
# episode:  298 score 290.21 average_score 182.44 epsilon 0.01
# episode:  299 score 264.36 average_score 184.39 epsilon 0.01
# episode:  300 score 267.80 average_score 184.46 epsilon 0.01
# episode:  301 score 34.81 average_score 182.27 epsilon 0.01
# episode:  302 score 262.53 average_score 182.03 epsilon 0.01
# episode:  303 score 277.95 average_score 182.72 epsilon 0.01
# episode:  304 score -30.78 average_score 179.52 epsilon 0.01
# episode:  305 score 31.95 average_score 176.99 epsilon 0.01
# episode:  306 score 228.78 average_score 176.47 epsilon 0.01
# episode:  307 score 256.54 average_score 176.52 epsilon 0.01
# episode:  308 score 210.30 average_score 178.54 epsilon 0.01
# episode:  309 score 283.05 average_score 181.31 epsilon 0.01
# episode:  310 score -98.19 average_score 180.14 epsilon 0.01
# episode:  311 score 300.49 average_score 180.67 epsilon 0.01
# episode:  312 score -137.44 average_score 180.68 epsilon 0.01
# episode:  313 score 12.44 average_score 178.96 epsilon 0.01
# episode:  314 score 273.15 average_score 181.08 epsilon 0.01
# episode:  315 score 269.99 average_score 181.18 epsilon 0.01
# episode:  316 score -147.56 average_score 179.11 epsilon 0.01
# episode:  317 score 262.56 average_score 181.84 epsilon 0.01
# episode:  318 score 285.45 average_score 184.80 epsilon 0.01
# episode:  319 score 235.40 average_score 187.57 epsilon 0.01
# episode:  320 score 247.52 average_score 190.06 epsilon 0.01
# episode:  321 score 248.89 average_score 189.62 epsilon 0.01
# episode:  322 score 313.12 average_score 190.40 epsilon 0.01
# episode:  323 score 46.66 average_score 188.21 epsilon 0.01
# episode:  324 score 249.67 average_score 191.11 epsilon 0.01
# episode:  325 score 258.30 average_score 191.04 epsilon 0.01
# episode:  326 score 274.45 average_score 191.40 epsilon 0.01
# episode:  327 score 279.40 average_score 195.25 epsilon 0.01
# episode:  328 score -125.82 average_score 194.22 epsilon 0.01
# episode:  329 score 289.32 average_score 195.46 epsilon 0.01
# episode:  330 score 246.34 average_score 198.33 epsilon 0.01
# episode:  331 score 262.05 average_score 199.02 epsilon 0.01
# episode:  332 score 272.85 average_score 199.56 epsilon 0.01
# episode:  333 score 276.66 average_score 200.78 epsilon 0.01
# episode:  334 score 303.90 average_score 201.21 epsilon 0.01
# episode:  335 score 274.96 average_score 201.71 epsilon 0.01
# episode:  336 score 157.99 average_score 200.88 epsilon 0.01
# episode:  337 score 270.99 average_score 201.09 epsilon 0.01
# episode:  338 score 266.56 average_score 201.75 epsilon 0.01
# episode:  339 score 286.99 average_score 202.66 epsilon 0.01
# episode:  340 score 283.50 average_score 203.00 epsilon 0.01
# episode:  341 score 271.79 average_score 203.36 epsilon 0.01
# episode:  342 score 225.10 average_score 203.24 epsilon 0.01
# episode:  343 score 238.39 average_score 203.03 epsilon 0.01
# episode:  344 score 231.78 average_score 202.81 epsilon 0.01
# episode:  345 score 249.94 average_score 202.98 epsilon 0.01
# episode:  346 score 278.31 average_score 203.28 epsilon 0.01
# episode:  347 score 280.33 average_score 203.40 epsilon 0.01
# episode:  348 score 267.54 average_score 203.52 epsilon 0.01
# episode:  349 score 271.50 average_score 203.96 epsilon 0.01
# episode:  350 score 256.92 average_score 203.87 epsilon 0.01
# episode:  351 score 256.09 average_score 204.07 epsilon 0.01
# episode:  352 score 250.11 average_score 204.92 epsilon 0.01
# episode:  353 score 282.42 average_score 205.07 epsilon 0.01
# episode:  354 score 240.95 average_score 207.89 epsilon 0.01
# episode:  355 score 301.66 average_score 208.12 epsilon 0.01
# episode:  356 score 256.72 average_score 208.36 epsilon 0.01
# episode:  357 score 217.83 average_score 207.88 epsilon 0.01
# episode:  358 score 275.03 average_score 208.01 epsilon 0.01
# episode:  359 score -288.06 average_score 202.63 epsilon 0.01
# episode:  360 score 51.06 average_score 200.34 epsilon 0.01
# episode:  361 score 273.72 average_score 200.58 epsilon 0.01
# episode:  362 score 273.18 average_score 200.71 epsilon 0.01
# episode:  363 score 275.60 average_score 200.95 epsilon 0.01
# episode:  364 score 284.50 average_score 202.85 epsilon 0.01
# episode:  365 score 264.22 average_score 202.53 epsilon 0.01
# episode:  366 score 268.94 average_score 206.31 epsilon 0.01
# episode:  367 score 274.00 average_score 206.92 epsilon 0.01
# episode:  368 score 283.86 average_score 207.08 epsilon 0.01
# episode:  369 score 320.52 average_score 207.90 epsilon 0.01
# episode:  370 score 260.30 average_score 207.62 epsilon 0.01
# episode:  371 score 266.44 average_score 207.72 epsilon 0.01
# episode:  372 score 284.12 average_score 208.16 epsilon 0.01
# episode:  373 score 249.59 average_score 207.68 epsilon 0.01
# episode:  374 score 25.16 average_score 206.03 epsilon 0.01
# episode:  375 score 244.83 average_score 206.53 epsilon 0.01
# episode:  376 score -96.07 average_score 207.61 epsilon 0.01
# episode:  377 score 267.67 average_score 207.69 epsilon 0.01
# episode:  378 score 261.24 average_score 208.02 epsilon 0.01
# episode:  379 score 253.93 average_score 207.77 epsilon 0.01
# episode:  380 score 276.39 average_score 208.05 epsilon 0.01
# episode:  381 score 30.53 average_score 206.30 epsilon 0.01
# episode:  382 score 286.60 average_score 206.28 epsilon 0.01
# episode:  383 score 298.56 average_score 206.64 epsilon 0.01
# episode:  384 score 254.55 average_score 206.66 epsilon 0.01
# episode:  385 score 279.03 average_score 209.13 epsilon 0.01
# episode:  386 score 245.56 average_score 208.73 epsilon 0.01
# episode:  387 score 274.99 average_score 208.48 epsilon 0.01
# episode:  388 score -133.04 average_score 207.26 epsilon 0.01
# episode:  389 score 304.23 average_score 211.83 epsilon 0.01
# episode:  390 score 280.25 average_score 211.80 epsilon 0.01
# episode:  391 score 254.84 average_score 212.80 epsilon 0.01
# episode:  392 score 274.01 average_score 213.07 epsilon 0.01
# episode:  393 score 257.80 average_score 218.07 epsilon 0.01
# episode:  394 score 265.95 average_score 218.19 epsilon 0.01
# episode:  395 score 274.57 average_score 218.07 epsilon 0.01
# episode:  396 score 247.11 average_score 217.97 epsilon 0.01
# episode:  397 score 293.19 average_score 218.34 epsilon 0.01
# episode:  398 score 301.44 average_score 218.46 epsilon 0.01
# episode:  399 score 282.54 average_score 218.64 epsilon 0.01
# episode:  400 score 264.94 average_score 218.61 epsilon 0.01
# episode:  401 score 234.06 average_score 220.60 epsilon 0.01
# episode:  402 score 275.41 average_score 220.73 epsilon 0.01
# episode:  403 score 294.59 average_score 220.90 epsilon 0.01
# episode:  404 score 269.36 average_score 223.90 epsilon 0.01
# episode:  405 score 197.38 average_score 225.55 epsilon 0.01
# episode:  406 score 201.06 average_score 225.28 epsilon 0.01
# episode:  407 score 253.53 average_score 225.25 epsilon 0.01
# episode:  408 score 222.02 average_score 225.36 epsilon 0.01
# episode:  409 score 12.42 average_score 222.66 epsilon 0.01
# episode:  410 score 288.66 average_score 226.53 epsilon 0.01
# episode:  411 score 226.07 average_score 225.78 epsilon 0.01
# episode:  412 score 233.64 average_score 229.49 epsilon 0.01
# episode:  413 score 239.85 average_score 231.77 epsilon 0.01
# episode:  414 score 276.10 average_score 231.80 epsilon 0.01
# episode:  415 score 224.00 average_score 231.34 epsilon 0.01
# episode:  416 score 305.90 average_score 235.87 epsilon 0.01
# episode:  417 score 252.88 average_score 235.77 epsilon 0.01
# episode:  418 score 264.29 average_score 235.56 epsilon 0.01
# episode:  419 score 306.23 average_score 236.27 epsilon 0.01
# episode:  420 score 276.16 average_score 236.56 epsilon 0.01
# episode:  421 score 2.52 average_score 234.09 epsilon 0.01
# episode:  422 score 0.14 average_score 230.96 epsilon 0.01
# episode:  423 score 256.97 average_score 233.07 epsilon 0.01
# episode:  424 score 272.00 average_score 233.29 epsilon 0.01
# episode:  425 score 306.89 average_score 233.77 epsilon 0.01
# episode:  426 score 199.26 average_score 233.02 epsilon 0.01
# episode:  427 score 287.05 average_score 233.10 epsilon 0.01
# episode:  428 score 203.27 average_score 236.39 epsilon 0.01
# episode:  429 score 275.50 average_score 236.25 epsilon 0.01
# episode:  430 score 291.73 average_score 236.71 epsilon 0.01
# episode:  431 score 261.33 average_score 236.70 epsilon 0.01
# episode:  432 score 269.01 average_score 236.66 epsilon 0.01
# episode:  433 score 274.61 average_score 236.64 epsilon 0.01
# episode:  434 score 165.75 average_score 235.26 epsilon 0.01
# episode:  435 score 252.77 average_score 235.04 epsilon 0.01
# episode:  436 score 246.16 average_score 235.92 epsilon 0.01
# episode:  437 score 299.81 average_score 236.21 epsilon 0.01
# episode:  438 score 292.77 average_score 236.47 epsilon 0.01
# episode:  439 score 97.85 average_score 234.58 epsilon 0.01
# episode:  440 score 296.68 average_score 234.71 epsilon 0.01
# episode:  441 score 275.27 average_score 234.74 epsilon 0.01
# episode:  442 score 302.80 average_score 235.52 epsilon 0.01
# episode:  443 score 301.58 average_score 236.15 epsilon 0.01
# episode:  444 score 271.85 average_score 236.55 epsilon 0.01
# episode:  445 score 230.57 average_score 236.36 epsilon 0.01
# episode:  446 score 283.22 average_score 236.41 epsilon 0.01
# episode:  447 score 264.64 average_score 236.25 epsilon 0.01
# episode:  448 score 283.80 average_score 236.41 epsilon 0.01
# episode:  449 score 244.53 average_score 236.15 epsilon 0.01
# episode:  450 score 38.81 average_score 233.96 epsilon 0.01
# episode:  451 score 279.80 average_score 234.20 epsilon 0.01
# episode:  452 score 302.08 average_score 234.72 epsilon 0.01
# episode:  453 score 304.23 average_score 234.94 epsilon 0.01
# episode:  454 score 281.80 average_score 235.35 epsilon 0.01
# episode:  455 score 250.40 average_score 234.83 epsilon 0.01
# episode:  456 score 295.28 average_score 235.22 epsilon 0.01
# episode:  457 score 95.40 average_score 234.00 epsilon 0.01
# episode:  458 score 28.85 average_score 231.53 epsilon 0.01
# episode:  459 score 294.51 average_score 237.36 epsilon 0.01
# episode:  460 score 293.82 average_score 239.79 epsilon 0.01
# episode:  461 score 262.31 average_score 239.67 epsilon 0.01
# episode:  462 score 290.67 average_score 239.85 epsilon 0.01
# episode:  463 score 231.43 average_score 239.41 epsilon 0.01
# episode:  464 score 288.79 average_score 239.45 epsilon 0.01
# episode:  465 score 226.80 average_score 239.08 epsilon 0.01
# episode:  466 score 293.87 average_score 239.32 epsilon 0.01
# episode:  467 score 277.34 average_score 239.36 epsilon 0.01
# episode:  468 score 247.03 average_score 238.99 epsilon 0.01
# episode:  469 score 269.58 average_score 238.48 epsilon 0.01
# episode:  470 score 300.53 average_score 238.88 epsilon 0.01
# episode:  471 score 318.96 average_score 239.41 epsilon 0.01
# episode:  472 score 309.74 average_score 239.66 epsilon 0.01
# episode:  473 score 288.46 average_score 240.05 epsilon 0.01
# episode:  474 score 246.90 average_score 242.27 epsilon 0.01
# episode:  475 score 266.75 average_score 242.49 epsilon 0.01
# episode:  476 score 306.67 average_score 246.52 epsilon 0.01
# episode:  477 score 290.53 average_score 246.75 epsilon 0.01
# episode:  478 score 274.08 average_score 246.87 epsilon 0.01
# episode:  479 score 256.14 average_score 246.90 epsilon 0.01
# episode:  480 score 260.67 average_score 246.74 epsilon 0.01
# episode:  481 score 268.39 average_score 249.12 epsilon 0.01
# episode:  482 score 308.19 average_score 249.33 epsilon 0.01
# episode:  483 score 319.30 average_score 249.54 epsilon 0.01
# episode:  484 score 270.05 average_score 249.70 epsilon 0.01
# episode:  485 score 252.38 average_score 249.43 epsilon 0.01
# episode:  486 score 48.12 average_score 247.45 epsilon 0.01
# episode:  487 score 62.48 average_score 245.33 epsilon 0.01
# episode:  488 score 275.96 average_score 249.42 epsilon 0.01
# episode:  489 score 299.42 average_score 249.37 epsilon 0.01
# episode:  490 score 14.48 average_score 246.71 epsilon 0.01
# episode:  491 score 213.37 average_score 246.30 epsilon 0.01
# episode:  492 score 318.13 average_score 246.74 epsilon 0.01
# episode:  493 score 296.56 average_score 247.13 epsilon 0.01
# episode:  494 score 268.73 average_score 247.16 epsilon 0.01
# episode:  495 score 289.59 average_score 247.31 epsilon 0.01
# episode:  496 score 302.39 average_score 247.86 epsilon 0.01
# episode:  497 score 247.92 average_score 247.41 epsilon 0.01
# episode:  498 score 259.90 average_score 246.99 epsilon 0.01
# episode:  499 score 234.69 average_score 246.51 epsilon 0.01

# %%
import matplotlib.pyplot as plt

x = [i+1 for i in range(n_games)]
plt.plot(x, scores)
plt.title("Curva de aprendizado")
plt.xlabel("Número de Jogos")
plt.ylabel("Pontuação")
plt.savefig(fname="learning_curve")
plt.show()

# %%
# Jogando o jogo:

done = False
score = 0
observation = env.reset()
while not done:
    action = agent.escolher_acao(observation)
    observation_, reward, done, info = env.step(action)
    env.render()
    score += reward
    observation = observation_
print("Score: ", score)
env.close()
# Out:
# Score:  243.99913474493565
